# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

# %%
# Perform an API call with the OpenWeatherMap

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the Latitude and longitude, Maximum temperature, Percent humidity, Percent cloudiness, Wind speed, Weather description

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | old shinyanga
# Processing Record 3 of Set 1 | atar
# Processing Record 4 of Set 1 | burica
# City not found. Skipping...
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | vao
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | vanimo
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | farafangana
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | presidencia roque saenz pena
# Processing Record 23 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 1 | gamba
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | linda
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | dok kham tai
# Processing Record 34 of Set 1 | san carlos de bariloche
# Processing Record 35 of Set 1 | te anau
# Processing Record 36 of Set 1 | persianovskiy
# Processing Record 37 of Set 1 | tarko-sale
# Processing Record 38 of Set 1 | mount gambier
# Processing Record 39 of Set 1 | trelew
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | hopewell
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | moose factory
# Processing Record 45 of Set 1 | xuddur
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | hirara
# Processing Record 48 of Set 1 | catuday
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | abu kamal
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | wilmington
# Processing Record 4 of Set 2 | alyangula
# Processing Record 5 of Set 2 | choya
# Processing Record 6 of Set 2 | khani
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | byron bay
# Processing Record 9 of Set 2 | goderich
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | paredon
# Processing Record 12 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 2 | northam
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | kavieng
# Processing Record 21 of Set 2 | portoferraio
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | valle de allende
# Processing Record 24 of Set 2 | alta
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | fortuna
# Processing Record 27 of Set 2 | jumla
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | pital
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | chapais
# Processing Record 32 of Set 2 | abu dhabi
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | salalah
# Processing Record 35 of Set 2 | teya
# Processing Record 36 of Set 2 | saint anthony
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | ahipara
# Processing Record 39 of Set 2 | gashua
# Processing Record 40 of Set 2 | kidal
# Processing Record 41 of Set 2 | high prairie
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 2 | jamestown
# Processing Record 45 of Set 2 | rocha
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | sao joao da barra
# Processing Record 4 of Set 3 | sabang
# Processing Record 5 of Set 3 | tromso
# Processing Record 6 of Set 3 | awjilah
# Processing Record 7 of Set 3 | bengkulu
# Processing Record 8 of Set 3 | constitucion
# Processing Record 9 of Set 3 | punta arenas
# Processing Record 10 of Set 3 | summerland
# Processing Record 11 of Set 3 | murdochville
# Processing Record 12 of Set 3 | yulara
# Processing Record 13 of Set 3 | aimores
# Processing Record 14 of Set 3 | nizwa
# Processing Record 15 of Set 3 | xinmin
# Processing Record 16 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 3 | kavaratti
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | lancaster
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | chatham
# Processing Record 23 of Set 3 | paka
# Processing Record 24 of Set 3 | schlitz
# Processing Record 25 of Set 3 | taksimo
# Processing Record 26 of Set 3 | teguise
# Processing Record 27 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 3 | batagay-alyta
# Processing Record 29 of Set 3 | sinnamary
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | picayune
# Processing Record 32 of Set 3 | preobrazheniye
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | san julian
# Processing Record 35 of Set 3 | peterhead
# Processing Record 36 of Set 3 | busselton
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | port augusta
# Processing Record 39 of Set 3 | port hawkesbury
# Processing Record 40 of Set 3 | tocopilla
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | flinders
# Processing Record 43 of Set 3 | vila velha
# Processing Record 44 of Set 3 | labuhan
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 3 | mareeba
# Processing Record 49 of Set 3 | moyale
# Processing Record 50 of Set 3 | huangchuan
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | shubarkuduk
# Processing Record 4 of Set 4 | tiarei
# Processing Record 5 of Set 4 | albany
# Processing Record 6 of Set 4 | bandarbeyla
# Processing Record 7 of Set 4 | itupiranga
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | zelion
# City not found. Skipping...
# Processing Record 10 of Set 4 | morro bay
# Processing Record 11 of Set 4 | clyde river
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | iracoubo
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | ust-maya
# Processing Record 17 of Set 4 | port elizabeth
# Processing Record 18 of Set 4 | chimore
# Processing Record 19 of Set 4 | hofn
# Processing Record 20 of Set 4 | gat
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | novikovo
# Processing Record 23 of Set 4 | kieta
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | belaya gora
# Processing Record 26 of Set 4 | zeerust
# Processing Record 27 of Set 4 | kapaa
# Processing Record 28 of Set 4 | porteirinha
# Processing Record 29 of Set 4 | priverno
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 4 | aksu
# Processing Record 33 of Set 4 | wangaratta
# Processing Record 34 of Set 4 | azar shahr
# City not found. Skipping...
# Processing Record 35 of Set 4 | omsukchan
# Processing Record 36 of Set 4 | sai buri
# Processing Record 37 of Set 4 | ugoofaaru
# Processing Record 38 of Set 4 | pangkalanbuun
# Processing Record 39 of Set 4 | svetlyy
# Processing Record 40 of Set 4 | magadan
# Processing Record 41 of Set 4 | zaventem
# Processing Record 42 of Set 4 | svetlaya
# Processing Record 43 of Set 4 | leh
# Processing Record 44 of Set 4 | plastun
# Processing Record 45 of Set 4 | amazar
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | ambon
# Processing Record 49 of Set 4 | walvis bay
# Processing Record 50 of Set 4 | namibe
# Processing Record 1 of Set 5 | tautira
# Processing Record 2 of Set 5 | pangody
# Processing Record 3 of Set 5 | melfort
# Processing Record 4 of Set 5 | chibuto
# Processing Record 5 of Set 5 | patea
# Processing Record 6 of Set 5 | vestmannaeyjar
# Processing Record 7 of Set 5 | grand gaube
# Processing Record 8 of Set 5 | umm lajj
# Processing Record 9 of Set 5 | san policarpo
# Processing Record 10 of Set 5 | bonnyville
# Processing Record 11 of Set 5 | ballina
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | poum
# Processing Record 14 of Set 5 | kyra
# Processing Record 15 of Set 5 | meru
# Processing Record 16 of Set 5 | akyab
# Processing Record 17 of Set 5 | tura
# Processing Record 18 of Set 5 | lakatoro
# Processing Record 19 of Set 5 | kirkwall
# Processing Record 20 of Set 5 | tselinnoye
# Processing Record 21 of Set 5 | komsomolskiy
# Processing Record 22 of Set 5 | high rock
# Processing Record 23 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 24 of Set 5 | salina
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | asgabat
# Processing Record 27 of Set 5 | port blair
# Processing Record 28 of Set 5 | asau
# Processing Record 29 of Set 5 | chokurdakh
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | katima mulilo
# Processing Record 32 of Set 5 | hami
# Processing Record 33 of Set 5 | liverpool
# Processing Record 34 of Set 5 | kropotkin
# Processing Record 35 of Set 5 | saskylakh
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | erenhot
# Processing Record 38 of Set 5 | mogadishu
# Processing Record 39 of Set 5 | praia
# Processing Record 40 of Set 5 | puerto escondido
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | tasiilaq
# Processing Record 43 of Set 5 | ust-tsilma
# Processing Record 44 of Set 5 | mulege
# Processing Record 45 of Set 5 | montes altos
# Processing Record 46 of Set 5 | kholtoson
# Processing Record 47 of Set 5 | morehead
# Processing Record 48 of Set 5 | kisangani
# Processing Record 49 of Set 5 | mitu
# Processing Record 50 of Set 5 | georgetown
# Processing Record 1 of Set 6 | canto do buriti
# Processing Record 2 of Set 6 | sorland
# Processing Record 3 of Set 6 | la ronge
# Processing Record 4 of Set 6 | zhangye
# Processing Record 5 of Set 6 | suffolk
# Processing Record 6 of Set 6 | praia da vitoria
# Processing Record 7 of Set 6 | oktyabrskiy
# Processing Record 8 of Set 6 | vardo
# Processing Record 9 of Set 6 | beitbridge
# Processing Record 10 of Set 6 | tumut
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | deputatskiy
# Processing Record 13 of Set 6 | barguzin
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | ishigaki
# Processing Record 16 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 6 | balykshi
# Processing Record 18 of Set 6 | talnakh
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | shimoda
# Processing Record 21 of Set 6 | bambous virieux
# Processing Record 22 of Set 6 | nhamunda
# Processing Record 23 of Set 6 | kuching
# Processing Record 24 of Set 6 | nantucket
# Processing Record 25 of Set 6 | port hardy
# Processing Record 26 of Set 6 | halifax
# Processing Record 27 of Set 6 | haines junction
# Processing Record 28 of Set 6 | imeni poliny osipenko
# Processing Record 29 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 30 of Set 6 | hammerfest
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | cabo san lucas
# Processing Record 33 of Set 6 | tanda
# Processing Record 34 of Set 6 | sainte-suzanne
# Processing Record 35 of Set 6 | villafranca de los barros
# Processing Record 36 of Set 6 | the valley
# Processing Record 37 of Set 6 | yamada
# Processing Record 38 of Set 6 | najran
# Processing Record 39 of Set 6 | mahibadhoo
# Processing Record 40 of Set 6 | sotara
# City not found. Skipping...
# Processing Record 41 of Set 6 | newport
# Processing Record 42 of Set 6 | kostomuksha
# Processing Record 43 of Set 6 | san gabriel
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | san cristobal
# Processing Record 46 of Set 6 | soweto
# Processing Record 47 of Set 6 | bengkalis
# City not found. Skipping...
# Processing Record 48 of Set 6 | vung tau
# Processing Record 49 of Set 6 | rantepao
# Processing Record 50 of Set 6 | saint austell
# Processing Record 1 of Set 7 | saurimo
# Processing Record 2 of Set 7 | aykhal
# Processing Record 3 of Set 7 | treinta y tres
# Processing Record 4 of Set 7 | pitimbu
# Processing Record 5 of Set 7 | havelock
# Processing Record 6 of Set 7 | saravan
# Processing Record 7 of Set 7 | vila do maio
# Processing Record 8 of Set 7 | asayita
# City not found. Skipping...
# Processing Record 9 of Set 7 | lvov
# Processing Record 10 of Set 7 | hithadhoo
# Processing Record 11 of Set 7 | chatellerault
# Processing Record 12 of Set 7 | bubaque
# Processing Record 13 of Set 7 | maniitsoq
# Processing Record 14 of Set 7 | uyuni
# Processing Record 15 of Set 7 | acarau
# Processing Record 16 of Set 7 | lensk
# Processing Record 17 of Set 7 | lincoln
# Processing Record 18 of Set 7 | zaysan
# Processing Record 19 of Set 7 | gigmoto
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | xiongzhou
# Processing Record 22 of Set 7 | kalmunai
# Processing Record 23 of Set 7 | raudeberg
# Processing Record 24 of Set 7 | ripoll
# Processing Record 25 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 26 of Set 7 | am timan
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | whitehorse
# Processing Record 29 of Set 7 | gunjur
# Processing Record 30 of Set 7 | souillac
# Processing Record 31 of Set 7 | tuatapere
# Processing Record 32 of Set 7 | qui nhon
# Processing Record 33 of Set 7 | imbituba
# Processing Record 34 of Set 7 | katsuura
# Processing Record 35 of Set 7 | kushima
# Processing Record 36 of Set 7 | ballybofey
# Processing Record 37 of Set 7 | key west
# Processing Record 38 of Set 7 | sumkino
# Processing Record 39 of Set 7 | severomuysk
# Processing Record 40 of Set 7 | mocuba
# Processing Record 41 of Set 7 | devarkonda
# Processing Record 42 of Set 7 | berlevag
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | tynda
# Processing Record 45 of Set 7 | kumla
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | thinadhoo
# Processing Record 48 of Set 7 | kimbe
# Processing Record 49 of Set 7 | qaanaaq
# Processing Record 50 of Set 7 | novopokrovka
# Processing Record 1 of Set 8 | east london
# Processing Record 2 of Set 8 | bonavista
# Processing Record 3 of Set 8 | yeppoon
# Processing Record 4 of Set 8 | tirschenreuth
# Processing Record 5 of Set 8 | hailun
# Processing Record 6 of Set 8 | porbandar
# Processing Record 7 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 8 | henties bay
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | abha
# Processing Record 11 of Set 8 | villa union
# Processing Record 12 of Set 8 | maxixe
# Processing Record 13 of Set 8 | itarema
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | bodden town
# Processing Record 16 of Set 8 | san patricio
# Processing Record 17 of Set 8 | kulhudhuffushi
# Processing Record 18 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 19 of Set 8 | domna
# Processing Record 20 of Set 8 | paciran
# Processing Record 21 of Set 8 | atbasar
# Processing Record 22 of Set 8 | garango
# Processing Record 23 of Set 8 | quatre cocos
# Processing Record 24 of Set 8 | ranong
# Processing Record 25 of Set 8 | darab
# Processing Record 26 of Set 8 | zelenoborsk
# Processing Record 27 of Set 8 | wajima
# Processing Record 28 of Set 8 | lokosovo
# Processing Record 29 of Set 8 | khandyga
# Processing Record 30 of Set 8 | rafai
# Processing Record 31 of Set 8 | coahuayana
# Processing Record 32 of Set 8 | dubuque
# Processing Record 33 of Set 8 | pontian kecil
# Processing Record 34 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 35 of Set 8 | avenal
# Processing Record 36 of Set 8 | hambantota
# Processing Record 37 of Set 8 | bograd
# Processing Record 38 of Set 8 | beringovskiy
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | rio grande
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | dioknisi
# Processing Record 43 of Set 8 | borogontsy
# Processing Record 44 of Set 8 | tucumcari
# Processing Record 45 of Set 8 | nikolsk
# Processing Record 46 of Set 8 | cabedelo
# Processing Record 47 of Set 8 | bend
# Processing Record 48 of Set 8 | fairbanks
# Processing Record 49 of Set 8 | raigarh
# Processing Record 50 of Set 8 | agadez
# Processing Record 1 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 9 | makakilo city
# Processing Record 3 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 4 of Set 9 | de-kastri
# Processing Record 5 of Set 9 | yumen
# Processing Record 6 of Set 9 | udachnyy
# Processing Record 7 of Set 9 | sorong
# Processing Record 8 of Set 9 | kununurra
# Processing Record 9 of Set 9 | zhigansk
# Processing Record 10 of Set 9 | ewo
# Processing Record 11 of Set 9 | cortez
# Processing Record 12 of Set 9 | mbanza-ngungu
# Processing Record 13 of Set 9 | amli
# Processing Record 14 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 9 | usinsk
# Processing Record 16 of Set 9 | san juan del sur
# Processing Record 17 of Set 9 | stephenville crossing
# Processing Record 18 of Set 9 | arman
# Processing Record 19 of Set 9 | sarangani
# Processing Record 20 of Set 9 | flin flon
# Processing Record 21 of Set 9 | saint-francois
# Processing Record 22 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 9 | aras
# Processing Record 24 of Set 9 | laguna
# Processing Record 25 of Set 9 | husavik
# Processing Record 26 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 9 | sept-iles
# Processing Record 28 of Set 9 | gladstone
# Processing Record 29 of Set 9 | the pas
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | puerto quijarro
# Processing Record 32 of Set 9 | khatanga
# Processing Record 33 of Set 9 | diebougou
# Processing Record 34 of Set 9 | pimentel
# Processing Record 35 of Set 9 | camocim
# Processing Record 36 of Set 9 | kuminskiy
# Processing Record 37 of Set 9 | gorontalo
# Processing Record 38 of Set 9 | mersin
# Processing Record 39 of Set 9 | kizema
# Processing Record 40 of Set 9 | camacupa
# Processing Record 41 of Set 9 | general pico
# Processing Record 42 of Set 9 | sharqpur
# Processing Record 43 of Set 9 | nainpur
# Processing Record 44 of Set 9 | anadyr
# Processing Record 45 of Set 9 | ardakan
# Processing Record 46 of Set 9 | mahebourg
# Processing Record 47 of Set 9 | la rioja
# Processing Record 48 of Set 9 | soyo
# Processing Record 49 of Set 9 | along
# Processing Record 50 of Set 9 | waingapu
# Processing Record 1 of Set 10 | vagay
# Processing Record 2 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 4 of Set 10 | fernley
# Processing Record 5 of Set 10 | nanortalik
# Processing Record 6 of Set 10 | eyl
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | narsaq
# Processing Record 9 of Set 10 | college
# Processing Record 10 of Set 10 | eastlake
# Processing Record 11 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 12 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 13 of Set 10 | prokopyevsk
# Processing Record 14 of Set 10 | lavrentiya
# Processing Record 15 of Set 10 | krasnaya gorbatka
# Processing Record 16 of Set 10 | dzhalil
# Processing Record 17 of Set 10 | sibolga
# Processing Record 18 of Set 10 | itanhaem
# Processing Record 19 of Set 10 | yar-sale
# Processing Record 20 of Set 10 | catio
# Processing Record 21 of Set 10 | pak thong chai
# Processing Record 22 of Set 10 | brezovica pri ljubljani
# Processing Record 23 of Set 10 | birjand
# Processing Record 24 of Set 10 | colares
# Processing Record 25 of Set 10 | takoradi
# Processing Record 26 of Set 10 | itoman
# Processing Record 27 of Set 10 | tutoia
# Processing Record 28 of Set 10 | jos
# Processing Record 29 of Set 10 | bowen
# Processing Record 30 of Set 10 | ostrovnoy
# Processing Record 31 of Set 10 | lumphat
# Processing Record 32 of Set 10 | moche
# Processing Record 33 of Set 10 | villa carlos paz
# Processing Record 34 of Set 10 | kitimat
# Processing Record 35 of Set 10 | truth or consequences
# Processing Record 36 of Set 10 | salinopolis
# Processing Record 37 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 10 | necochea
# Processing Record 39 of Set 10 | yeniseysk
# Processing Record 40 of Set 10 | venice
# Processing Record 41 of Set 10 | koster
# Processing Record 42 of Set 10 | fjerritslev
# Processing Record 43 of Set 10 | bethel
# Processing Record 44 of Set 10 | pangnirtung
# Processing Record 45 of Set 10 | turayf
# Processing Record 46 of Set 10 | manokwari
# Processing Record 47 of Set 10 | new richmond
# Processing Record 48 of Set 10 | waw
# Processing Record 49 of Set 10 | mugumu
# Processing Record 50 of Set 10 | coos bay
# Processing Record 1 of Set 11 | kourou
# Processing Record 2 of Set 11 | pokhara
# Processing Record 3 of Set 11 | huarmey
# Processing Record 4 of Set 11 | manaia
# Processing Record 5 of Set 11 | bac can
# City not found. Skipping...
# Processing Record 6 of Set 11 | front royal
# Processing Record 7 of Set 11 | zhanaozen
# Processing Record 8 of Set 11 | wuwei
# Processing Record 9 of Set 11 | maneromango
# Processing Record 10 of Set 11 | alpena
# Processing Record 11 of Set 11 | rocky mountain house
# Processing Record 12 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 11 | kaduqli
# Processing Record 14 of Set 11 | nome
# Processing Record 15 of Set 11 | bose
# Processing Record 16 of Set 11 | puerto cabezas
# Processing Record 17 of Set 11 | ostersund
# Processing Record 18 of Set 11 | yangjiang
# Processing Record 19 of Set 11 | kysyl-syr
# Processing Record 20 of Set 11 | kenai
# Processing Record 21 of Set 11 | haradok
# Processing Record 22 of Set 11 | kaeo
# Processing Record 23 of Set 11 | zhifang
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | ushtobe
# Processing Record 26 of Set 11 | ullapool
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 11 | itaituba
# Processing Record 31 of Set 11 | kadhan
# Processing Record 32 of Set 11 | chippewa falls
# Processing Record 33 of Set 11 | san luis de la paz
# Processing Record 34 of Set 11 | kwinana
# Processing Record 35 of Set 11 | glenluce
# Processing Record 36 of Set 11 | gweta
# Processing Record 37 of Set 11 | moron
# Processing Record 38 of Set 11 | dawson creek
# Processing Record 39 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 11 | dongsheng
# Processing Record 41 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 42 of Set 11 | little current
# Processing Record 43 of Set 11 | qasigiannguit
# Processing Record 44 of Set 11 | mazyr
# Processing Record 45 of Set 11 | curuca
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | matara
# Processing Record 48 of Set 11 | carpinteria
# Processing Record 49 of Set 11 | jizan
# Processing Record 50 of Set 11 | mangawan
# Processing Record 1 of Set 12 | sao raimundo das mangabeiras
# Processing Record 2 of Set 12 | ixtapa
# Processing Record 3 of Set 12 | buchanan
# Processing Record 4 of Set 12 | beloha
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | taoudenni
# Processing Record 7 of Set 12 | kahului
# Processing Record 8 of Set 12 | valparaiso
# Processing Record 9 of Set 12 | anloga
# Processing Record 10 of Set 12 | kismayo
# Processing Record 11 of Set 12 | espanola
# Processing Record 12 of Set 12 | fairview
# Processing Record 13 of Set 12 | boyolangu
# Processing Record 14 of Set 12 | kananga
# Processing Record 15 of Set 12 | nioro
# Processing Record 16 of Set 12 | urucui
# Processing Record 17 of Set 12 | kamenka
# Processing Record 18 of Set 12 | rio muerto
# Processing Record 19 of Set 12 | hamilton
# Processing Record 20 of Set 12 | puno
# Processing Record 21 of Set 12 | guarapari
# Processing Record 22 of Set 12 | ifanadiana
# Processing Record 23 of Set 12 | aykino
# Processing Record 24 of Set 12 | rawson
# Processing Record 25 of Set 12 | berwick
# Processing Record 26 of Set 12 | olavarria
# Processing Record 27 of Set 12 | monrovia
# Processing Record 28 of Set 12 | bowmore
# Processing Record 29 of Set 12 | kasongo-lunda
# Processing Record 30 of Set 12 | ossora
# Processing Record 31 of Set 12 | oriximina
# Processing Record 32 of Set 12 | margate
# Processing Record 33 of Set 12 | awbari
# Processing Record 34 of Set 12 | port pirie
# Processing Record 35 of Set 12 | cockburn town
# Processing Record 36 of Set 12 | cedar city
# Processing Record 37 of Set 12 | cartagena del chaira
# Processing Record 38 of Set 12 | roald
# Processing Record 39 of Set 12 | cayenne
# Processing Record 40 of Set 12 | brazzaville
# Processing Record 41 of Set 12 | kashan
# Processing Record 42 of Set 12 | baijiantan
# Processing Record 43 of Set 12 | port-cartier
# Processing Record 44 of Set 12 | kamennogorsk
# Processing Record 45 of Set 12 | yaan
# Processing Record 46 of Set 12 | medzilaborce
# Processing Record 47 of Set 12 | atikokan
# Processing Record 48 of Set 12 | princeton
# Processing Record 49 of Set 12 | kindu
# Processing Record 50 of Set 12 | kirakira
# Processing Record 1 of Set 13 | norton
# Processing Record 2 of Set 13 | alice springs
# Processing Record 3 of Set 13 | touros
# Processing Record 4 of Set 13 | resavica
# Processing Record 5 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 13 | tezu
# Processing Record 7 of Set 13 | sovetskiy
# Processing Record 8 of Set 13 | yakeshi
# Processing Record 9 of Set 13 | calama
# Processing Record 10 of Set 13 | calvinia
# Processing Record 11 of Set 13 | mezen
# Processing Record 12 of Set 13 | bintulu
# Processing Record 13 of Set 13 | milledgeville
# Processing Record 14 of Set 13 | reconquista
# Processing Record 15 of Set 13 | elko
# Processing Record 16 of Set 13 | miramar
# Processing Record 17 of Set 13 | roswell
# Processing Record 18 of Set 13 | yatou
# Processing Record 19 of Set 13 | hede
# Processing Record 20 of Set 13 | mallapuram
# Processing Record 21 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 13 | ambilobe
# Processing Record 23 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | avera
# Processing Record 25 of Set 13 | baykit
# Processing Record 26 of Set 13 | vestmanna
# Processing Record 27 of Set 13 | sitka
# Processing Record 28 of Set 13 | conde
# Processing Record 29 of Set 13 | galle
# Processing Record 30 of Set 13 | richards bay
# Processing Record 31 of Set 13 | porto walter
# Processing Record 32 of Set 13 | houma
# Processing Record 33 of Set 13 | sarakhs
# Processing Record 34 of Set 13 | kvasice
# Processing Record 35 of Set 13 | witu
# Processing Record 36 of Set 13 | algiers
# Processing Record 37 of Set 13 | sistranda
# Processing Record 38 of Set 13 | atambua
# Processing Record 39 of Set 13 | miandrivazo
# Processing Record 40 of Set 13 | sioux lookout
# Processing Record 41 of Set 13 | jinchang
# Processing Record 42 of Set 13 | port arthur
# Processing Record 43 of Set 13 | meulaboh
# Processing Record 44 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 45 of Set 13 | mangan
# Processing Record 46 of Set 13 | los llanos de aridane
# Processing Record 47 of Set 13 | bonthe
# Processing Record 48 of Set 13 | sola
# Processing Record 49 of Set 13 | kang
# Processing Record 50 of Set 13 | caxito
# Processing Record 1 of Set 14 | esso
# Processing Record 2 of Set 14 | roma
# Processing Record 3 of Set 14 | shinpokh
# Processing Record 4 of Set 14 | priargunsk
# Processing Record 5 of Set 14 | guerrero negro
# Processing Record 6 of Set 14 | betare oya
# Processing Record 7 of Set 14 | kijang
# Processing Record 8 of Set 14 | noumea
# Processing Record 9 of Set 14 | poya
# Processing Record 10 of Set 14 | upata
# Processing Record 11 of Set 14 | bathsheba
# Processing Record 12 of Set 14 | mahajanga
# Processing Record 13 of Set 14 | manbij
# Processing Record 14 of Set 14 | casablanca
# Processing Record 15 of Set 14 | kitgum
# Processing Record 16 of Set 14 | presidente olegario
# Processing Record 17 of Set 14 | ulladulla
# Processing Record 18 of Set 14 | el alto
# Processing Record 19 of Set 14 | cuprija
# Processing Record 20 of Set 14 | vondrozo
# Processing Record 21 of Set 14 | vostok
# Processing Record 22 of Set 14 | staraya mayna
# Processing Record 23 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 14 | green river
# Processing Record 25 of Set 14 | san quintin
# Processing Record 26 of Set 14 | ayan
# Processing Record 27 of Set 14 | hualmay
# Processing Record 28 of Set 14 | baruun-urt
# Processing Record 29 of Set 14 | mount isa
# Processing Record 30 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 31 of Set 14 | keti bandar
# Processing Record 32 of Set 14 | olga
# Processing Record 33 of Set 14 | onega
# Processing Record 34 of Set 14 | garowe
# Processing Record 35 of Set 14 | san antonio
# Processing Record 36 of Set 14 | coari
# Processing Record 37 of Set 14 | wanning
# Processing Record 38 of Set 14 | buta
# Processing Record 39 of Set 14 | mantua
# Processing Record 40 of Set 14 | novoshcherbinovskaya
# Processing Record 41 of Set 14 | ayorou
# Processing Record 42 of Set 14 | sterling
# Processing Record 43 of Set 14 | cao bang
# Processing Record 44 of Set 14 | saldanha
# Processing Record 45 of Set 14 | plotnikovo
# Processing Record 46 of Set 14 | paraiso
# Processing Record 47 of Set 14 | lompoc
# Processing Record 48 of Set 14 | armizonskoye
# Processing Record 49 of Set 14 | port hedland
# Processing Record 50 of Set 14 | skjervoy
# Processing Record 1 of Set 15 | pathein
# Processing Record 2 of Set 15 | luanda
# Processing Record 3 of Set 15 | kaseda
# Processing Record 4 of Set 15 | moorhead
# Processing Record 5 of Set 15 | aloleng
# Processing Record 6 of Set 15 | busia
# Processing Record 7 of Set 15 | pestravka
# Processing Record 8 of Set 15 | artesia
# Processing Record 9 of Set 15 | andros town
# Processing Record 10 of Set 15 | lyangasovo
# Processing Record 11 of Set 15 | rio de janeiro
# Processing Record 12 of Set 15 | napier
# Processing Record 13 of Set 15 | sucua
# Processing Record 14 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 15 | karakose
# City not found. Skipping...
# Processing Record 16 of Set 15 | pochutla
# Processing Record 17 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | willowmore
# Processing Record 19 of Set 15 | ocos
# Processing Record 20 of Set 15 | lexington
# Processing Record 21 of Set 15 | pacific grove
# Processing Record 22 of Set 15 | george
# Processing Record 23 of Set 15 | araouane
# Processing Record 24 of Set 15 | nadym
# Processing Record 25 of Set 15 | cambui
# Processing Record 26 of Set 15 | praya
# Processing Record 27 of Set 15 | wakefield
# Processing Record 28 of Set 15 | zhigalovo
# Processing Record 29 of Set 15 | biak
# Processing Record 30 of Set 15 | sumbawanga
# Processing Record 31 of Set 15 | baherden
# Processing Record 32 of Set 15 | namatanai
# Processing Record 33 of Set 15 | zhangzhou
# Processing Record 34 of Set 15 | wang noi
# Processing Record 35 of Set 15 | tuburan
# Processing Record 36 of Set 15 | coro
# Processing Record 37 of Set 15 | hobyo
# Processing Record 38 of Set 15 | wattegama
# Processing Record 39 of Set 15 | lahij
# Processing Record 40 of Set 15 | fort collins
# Processing Record 41 of Set 15 | kingsland
# Processing Record 42 of Set 15 | okhotsk
# Processing Record 43 of Set 15 | saint-augustin
# Processing Record 44 of Set 15 | gravdal
# Processing Record 45 of Set 15 | palmer
# Processing Record 46 of Set 15 | portland
# Processing Record 47 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 15 | igarka
# Processing Record 49 of Set 15 | stepnyak
# Processing Record 50 of Set 15 | harper
# Processing Record 1 of Set 16 | arkhangelsk
# Processing Record 2 of Set 16 | bumba
# Processing Record 3 of Set 16 | awka
# Processing Record 4 of Set 16 | ponta delgada
# Processing Record 5 of Set 16 | mayor pablo lagerenza
# Processing Record 6 of Set 16 | fare
# Processing Record 7 of Set 16 | moussoro
# Processing Record 8 of Set 16 | oksovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Iqaluit      CA  63.7506  -68.5145     33.53        80
# 1            Old Shinyanga      TZ  -3.5500   33.4000     75.42        54
# 2                     Atar      MR  20.5169  -13.0499     86.02        15
# 3                  Rikitea      PF -23.1203 -134.9692     73.26        73
# 4                    Bluff      NZ -46.6000  168.3333     63.81        72
# ..                     ...     ...      ...       ...       ...       ...
# 696          Ponta Delgada      PT  37.7333  -25.6667     73.51        83
# 697  Mayor Pablo Lagerenza      PY -19.9309  -60.7718     58.15        58
# 698                   Fare      PF -16.7000 -151.0167     78.89        70
# 699               Moussoro      TD  13.6408   16.4901     85.84        50
# 700              Oksovskiy      RU  62.6062   39.8984     38.28        92
#
#      Cloudiness  Wind Speed Current Description
# 0            75        3.00       broken clouds
# 1            99        3.22     overcast clouds
# 2             0       11.41           clear sky
# 3           100       20.69     overcast clouds
# 4            29        9.33    scattered clouds
# ..          ...         ...                 ...
# 696          20        3.44          few clouds
# 697          96        5.61     overcast clouds
# 698           1       16.06           clear sky
# 699          87        6.22     overcast clouds
# 700           0        7.23           clear sky
#
# [701 rows x 9 columns]

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
